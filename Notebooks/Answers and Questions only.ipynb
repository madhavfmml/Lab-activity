# %% [markdown]
# #### Question 0:
# ###### write down 3-5 methods applicable to each data type. (Hint: extend, reverse, etc.
#
# ####List
# Extend-List
#
# Reverse-List
#
# Count-List

# %% [markdown]
# #### Question 1 :
#
# ##### Define a function, which takes in two strings A and B. Reverses the first string A, adds it to B, and returns the final string.
#
#
# #### Question 2 :
# ##### Given a list having Names, work_hours, and gender, Write a function to print name of the female worker that worked the most hours. Also how much do should she be paid if the pay is $ 20 per hour.
#
# ##### work_hours = [('Abby',100 , 'F'),('Billy',400, 'M'),('Cassie',800,'F'), ('Maggi',600,'F'),('Alex',500,'M'),('Raj',225,'M'),('Penny',920,'F'),('Ben',300,'M')]
#
# ##### Answer : the female worker that worked the most hours is Penny and she should be paid 18400

# %%
'''
Question 1 :
Define a function, which takes in two strings A and B. Reverses the first string A, adds it to B, and returns the final string.
'''


reverse_string=lambda a,b : a[::-1]+b
reverse_string(input().strip(),input().strip())
# Out:
#  Hello
#  world
# 'olleHworld'

# %%
work_hours= [('Abby',100 , 'F'),('Billy',400, 'M'),('Cassie',800,'F'), ('Maggi',600,'F'),('Alex',500,'M'),('Raj',225,'M'),('Penny',920,'F'),('Ben',300,'M')]
def find_longest_and_addpay(l):
  max=[]
  for i in l:
    if max==[] or i[1]>max[1]:
      max=i
  print(max)
  g="female" if max[2].lower()=='f' else 'Male'
  return f"{max[0]} gets paid ${max[1]*20} Gender is {g} "
find_longest_and_addpay(work_hours)
# Out:
# ('Penny', 920, 'F')
# 'Penny gets paid $18400 Gender is female '

# %% [markdown]
# #### Question 3 :
#
# ##### a)Create a 5x5 matrix of the following form,
#
# ##### [[1,1]
# #####  [2,2]]
#
# #####  i.e. each row is increasing and has repetive elements.
#
# ######  Hint : you can use hstack, vstack  etc.
#
# ##### b) find dot product of the matrix with any matrix. (Figure out the size/ shape of the matrix)

# %%
"""
Question 3 :
a)Create a 5x5 matrix of the following form,
[[1,1]
[2,2]]
"""
import numpy as np

a = np.array([[1],[2],[3],[4],[5]])
b = np.array([[1],[2],[3],[4],[5]])
c = np.array([[1],[2],[3],[4],[5]])
d = np.array([[1],[2],[3],[4],[5]])
e = np.array([[1],[2],[3],[4],[5]])
final_matrix=np.hstack((a,b,c,d,e))

# %%
def dot_product(a,b):
  return np.dot(a,b)
dot_product(final_matrix,final_matrix)
# Out:
# array([[15, 15, 15, 15, 15],
#        [30, 30, 30, 30, 30],
#        [45, 45, 45, 45, 45],
#        [60, 60, 60, 60, 60],
#        [75, 75, 75, 75, 75]])

# %%
## Question 3 : Upload an image to your google drive, Use plt.imread to read image from the google drive and then print that image using plt.imshow
import matplotlib.pyplot as plt
image_path="/content/Sample_image/tree-gf56a26791_1280.jpg"
i=plt.imread(image_path)
plt.imshow(i)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 image_path="/content/Sample_image/tree-gf56a26791_1280.jpg"
# ----> 4 i=plt.imread(image_path)
#       5 plt.imshow(i)
#
# File C:\Program Files\Python310\lib\site-packages\matplotlib\pyplot.py:2160, in imread(fname, format)
#    2158 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2159 def imread(fname, format=None):
# -> 2160     return matplotlib.image.imread(fname, format)
#
# File C:\Program Files\Python310\lib\site-packages\matplotlib\image.py:1560, in imread(fname, format)
#    1558                 response = io.BytesIO(response.read())
#    1559             return imread(response, format=ext)
# -> 1560 with img_open(fname) as image:
#    1561     return (_pil_png_to_float_array(image)
#    1562             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1563             pil_to_array(image))
#
# File C:\Program Files\Python310\lib\site-packages\PIL\Image.py:3068, in open(fp, mode, formats)
#    3065     filename = fp
#    3067 if filename:
# -> 3068     fp = builtins.open(filename, "rb")
#    3069     exclusive_fp = True
#    3071 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Sample_image/tree-gf56a26791_1280.jpg'

# %% [markdown]
# Normalize the i variable (read variable ) ie dividing by 255

# %%
import numpy as np
i=i.astype('float64')

# %%
i/=255

# %%
plt.imshow(i)
